# %% [markdown]
# # Install

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %%
# !git clone https://github.com/farzane-maghsoudi/UG

import os
os.chdir('UG/')

# !pip install -r requirements.txt

# %% [markdown]
# #dataset

# %%
# !bash ./download_dataset.sh apple2orange

# %% [markdown]
# #Training

# %%
# !python main.py --dataset apple2orange --light True

# %% [markdown]
# #Testing

# %%
# !python main.py --dataset apple2orange --phase test

# %% [markdown]
# #Visualize

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_1010_fake.png')
plt.imshow(img)

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_1010_real.png')
plt.imshow(img)

# %% [markdown]
# #Download

# %%
import os
aa = os.path.abspath(os.getcwd())
os.chdir('/content/UG/checkpoint/UGATIT_light_apple2orange_lsgan_4resblock_6dis_1_1_10_10_1000_1_1_1_sn_smoothing')
os.chdir('/content/UG')

# %%
os.chdir('/content/UG/checkpoint/UGATIT_light_apple2orange_lsgan_4resblock_6dis_1_1_10_10_1000_1_1_1_sn_smoothing')
from google.colab import files
#files.download('UGATIT_light.model-' + counter + '.index')
#files.download('UGATIT_light.model-' + counter + '.meta')
files.download('UGATIT_light.model-' + '5001' + '.data-00000-of-00001')

# %% [markdown]
# #Copy checkpoint to GoogleDrive and convert

# %%
from google.colab import drive
drive.mount("/content/gdrive")

# %%
a = 1001
b = "/content/gdrive/MyDrive/checkpoint/UGATIT_light_apple2orange_lsgan_4resblock_6dis_1_1_10_10_1000_1_1_1_sn_smoothing"
c = "/content/UG/checkpoint/UGATIT_light_apple2orange_lsgan_4resblock_6dis_1_1_10_10_1000_1_1_1_sn_smoothing"
f1 = "/UGATIT_light.model-"+ str(a)+ ".index"
f2 = "/UGATIT_light.model-"+ str(a)+ ".meta"
f3 = "/UGATIT_light.model-" + str(a)+ ".data-00000-of-00001"

# %% [markdown]
# Colab to Drive

# %%
import shutil
shutil.copy( c+f1 , b+f1 )
shutil.copy( c+f2 , b+f2 )
shutil.copy( c+f3 , b+f3 )

# %% [markdown]
# Drive to Colab

# %%
import shutil
shutil.copy( b+f1 , c+f1 )
shutil.copy( b+f2 , c+f2 )
shutil.copy( b+f3 , c+f3 )
